# %%
files = [
    "transactions_raw.csv",
    "customers_raw.json",
    "products_raw.csv"
]
base_url = "https://raw.githubusercontent.com/Karthika-mv/databricks-project/refs/heads/main/"
for f in files:
    dbutils.fs.cp(
        base_url + f,
        f"dbfs:/Volumes/databricks_project/schema/raw_data_volume/{f}"
    )
